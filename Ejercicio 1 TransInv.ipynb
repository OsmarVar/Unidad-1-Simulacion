# %% [markdown]
# <a href="https://colab.research.google.com/github/OsmarVar/Unidad-1-Simulacion/blob/main/Ejercicio%201%20TransInv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
def funcion(a = 10, b = 15):
     lista = []
     for i in range (n):
       U = rnd.random()
       x = ( b - a ) * U + a
       lista.append(x)
     return lista

# %%
A = funcion ( 0 , 1)

# %%
media = np.mean(A)

# %%
varianza = np.var(A)

# %%
plt.hist(A)
# Out:
# (array([ 95.,  95., 101.,  95.,  89., 101., 109., 113., 113.,  89.]),
#  array([1.89986038e-04, 1.00042407e-01, 1.99894827e-01, 2.99747247e-01,
#         3.99599668e-01, 4.99452088e-01, 5.99304509e-01, 6.99156929e-01,
#         7.99009350e-01, 8.98861770e-01, 9.98714191e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(A)
